# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# reading the data
df=pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df=df.rename(columns={"target":"heartstroke"})

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  heartstroke
# 0   2     3            0
# 1   0     3            0
# 2   0     3            0
# 3   1     3            0
# 4   3     2            0

# %%
heartstroke_map={1:True,0:False}
df["heartstroke"]=df["heartstroke"].map(heartstroke_map)

# %%
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
heartstroke_map={True:1,False:0}
df["heartstroke"]=df["heartstroke"].map(heartstroke_map)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  heartstroke
# 0   2     3            0
# 1   0     3            0
# 2   0     3            0
# 3   1     3            0
# 4   3     2            0

# %%
df.isnull().values.any()
# Out:
# False

# %%
import seaborn as sns
import matplotlib.pyplot as plt
arjun=df.corr()
top_corr_features=arjun.index
plt.figure(figsize=(20,10))
a=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.corr()
# Out:
#                   age       sex        cp  trestbps      chol       fbs  \
# age          1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex         -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp          -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps     0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol         0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs          0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg     -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach     -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang        0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak      0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope       -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca           0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# ...

# %%
df_true_counts=len(df.loc[df["heartstroke"]==True])
df_false_counts=len(df.loc[df["heartstroke"]==False])

# %%
(df_true_counts,df_false_counts)
# Out:
# (526, 499)

# %%
from sklearn.model_selection import train_test_split
feature_columns=[ "age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal" ]
predicted_class=["heartstroke"]

# %%
X=df[feature_columns].values
y=df[predicted_class].values

X_train,X_test,y_train,y_test=train_test_split(X,y.ravel(),test_size=0.3,random_state=0)

# %%
print("total number of 0 values :{0}".format(len(df)))
print("total number of 0 values in age :{0}".format(len(df.loc[df["age"]==0])))
print("total number of 0 values in sex :{0}".format(len(df.loc[df["sex"]==0])))  
print("total number of 0 values in cp :{0}".format(len(df.loc[df["cp"]==0])))
print("total number of 0 values in trestbps :{0}".format(len(df.loc[df["trestbps"]==0])))
print("total number of 0 values in chol:{0}".format(len(df.loc[df["chol"]==0])))
print("total number of 0 values in fbs:{0}".format(len(df.loc[df["fbs"]==0])))
print("total number of 0 values in restecg :{0}".format(len(df.loc[df["restecg"]==0])))     
print("total number of 0 values in thalach :{0}".format(len(df.loc[df["thalach"]==0])))     
print("total number of 0 values in exang :{0}".format(len(df.loc[df["exang"]==0])))     
print("total number of 0 values in oldpeak :{0}".format(len(df.loc[df["oldpeak"]==0])))
print("total number of 0 values in slope :{0}".format(len(df.loc[df["slope"]==0])))     
print("total number of 0 values in ca :{0}".format(len(df.loc[df["ca"]==0]))) 
print("total number of 0 values in thal:{0}".format(len(df.loc[df["thal"]==0])))
# Out:
# total number of 0 values :1025
# total number of 0 values in age :0
# total number of 0 values in sex :312
# total number of 0 values in cp :497
# total number of 0 values in trestbps :0
# total number of 0 values in chol:0
# total number of 0 values in fbs:872
# total number of 0 values in restecg :497
# total number of 0 values in thalach :0
# total number of 0 values in exang :680
# total number of 0 values in oldpeak :329
# total number of 0 values in slope :74
# total number of 0 values in ca :578
# total number of 0 values in thal:7

# %%
from sklearn.impute import SimpleImputer
fill_values = SimpleImputer(missing_values=0, strategy="mean")

X_train = fill_values.fit_transform(X_train)
X_test = fill_values.fit_transform(X_test)

# %%
X_train
# Out:
# array([[57.        ,  1.        ,  2.        , ...,  2.        ,
#          1.72468354,  2.        ],
#        [59.        ,  1.        ,  1.83468835, ...,  1.        ,
#          2.        ,  1.        ],
#        [71.        ,  1.        ,  1.83468835, ...,  1.        ,
#          1.72468354,  2.        ],
#        ...,
#        [65.        ,  1.        ,  3.        , ...,  1.        ,
#          1.        ,  2.        ],
#        [67.        ,  1.        ,  1.83468835, ...,  1.        ,
#          1.72468354,  2.        ],
#        [60.        ,  1.        ,  2.        , ...,  1.        ,
#          1.72468354,  2.        ]])

# %%
X_test
# Out:
# array([[44.        ,  1.        ,  2.        , ...,  2.        ,
#          1.74045802,  2.        ],
#        [58.        ,  1.        ,  1.        , ...,  2.        ,
#          2.        ,  2.        ],
#        [63.        ,  1.        ,  1.81761006, ...,  2.        ,
#          2.        ,  3.        ],
#        ...,
#        [56.        ,  1.        ,  2.        , ...,  1.        ,
#          1.        ,  1.        ],
#        [57.        ,  1.        ,  1.81761006, ...,  2.        ,
#          1.74045802,  2.        ],
#        [54.        ,  1.        ,  1.81761006, ...,  1.        ,
#          1.        ,  3.        ]])

# %%
from sklearn.ensemble import AdaBoostClassifier
arjuna=AdaBoostClassifier(n_estimators=700)
arjuna.fit(X_train,y_train)
prediction=arjuna.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction))
# Out:
# 0.9935064935064936

# %%
from logitboost import LogitBoost
arjuna=LogitBoost(n_estimators=700)
arjuna.fit(X_train,y_train)
prediction=arjuna.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction))
# Out:
# 0.9512987012987013

# %%
from sklearn.ensemble import RandomForestClassifier
arjuna=RandomForestClassifier(random_state=0)
arjuna.fit(X_train,y_train)
prediction=arjuna.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction))
# Out:
# 1.0
